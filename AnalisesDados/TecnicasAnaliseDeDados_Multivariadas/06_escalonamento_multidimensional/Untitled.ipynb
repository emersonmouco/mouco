# %%
import pandas as pd
from scipy.spatial.distance import pdist, squareform
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("matriz_distancia_formatada.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Carrega o arquivo gerado
# matriz = pd.read_csv("matriz_distancia_formatada.csv", index_col=0, sep=';')

# Plotagem
plt.figure(figsize=(8, 6))
sns.heatmap(df, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Matriz de Distância entre Categorias de Produtos")
plt.show()
