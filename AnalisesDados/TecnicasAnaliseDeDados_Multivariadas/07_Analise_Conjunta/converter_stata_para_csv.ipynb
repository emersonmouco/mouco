# %%
import pandas as pd
data = pd.read_stata('candidate.dta')
data.to_csv('teste.csv')

# %%
df = pd.read_csv("teste.csv")

# %%
df
# Out:
#         ID           resID     atmilitary           atreligion  \
# 0        0  A2NEN4NSNS2O8S  Did Not Serve               Mormon
# 1        1  A2NEN4NSNS2O8S         Served                 None
# 2        2  A2NEN4NSNS2O8S  Did Not Serve             Catholic
# 3        3  A2NEN4NSNS2O8S         Served  Mainline protestant
# 4        4  A2NEN4NSNS2O8S         Served                 None
# ...    ...             ...            ...                  ...
# 3461  3461  A1CDHU1KJTE1IJ         Served             Catholic
# 3462  3462  A1CDHU1KJTE1IJ  Did Not Serve               Jewish
# 3463  3463  A1CDHU1KJTE1IJ         Served  Mainline protestant
# 3464  3464  A1CDHU1KJTE1IJ         Served               Mormon
# 3465  3465  A1CDHU1KJTE1IJ         Served  Mainline protestant
#
#                        ated               atprof atinc           atrace  \
# 0         Community college           Car dealer  5.1M            White
# ...
