# %%
import joblib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("periodo_2000_a_2002.csv")

# %%
df
# Out:
#          country  life_expectancy  year      status  adult_mortality  \
# 0    Afghanistan        55.433333  2002  Developing       213.333333
# 1    Afghanistan        55.433333  2001  Developing       213.333333
# 2    Afghanistan        55.433333  2000  Developing       213.333333
# 3        Albania        73.166667  2002  Developing        13.333333
# 4        Albania        73.166667  2001  Developing        13.333333
# ..           ...              ...   ...         ...              ...
# 544       Zambia        44.633333  2001  Developing       431.333333
# 545       Zambia        44.633333  2000  Developing       431.333333
# 546     Zimbabwe        45.366667  2002  Developing       474.666667
# 547     Zimbabwe        45.366667  2001  Developing       474.666667
# 548     Zimbabwe        45.366667  2000  Developing       474.666667
#
#      inf_death   alcohol  hepatitisB       measles        bmi      polio  \
# 0    88.000000  0.010000        63.0   5926.666667  12.600000  31.666667
# 1    88.000000  0.010000        63.0   5926.666667  12.600000  31.666667
# 2    88.000000  0.010000        63.0   5926.666667  12.600000  31.666667
# 3     1.000000  3.880000        96.0    232.000000  45.966667  97.333333
# 4     1.000000  3.880000        96.0    232.000000  45.966667  97.333333
# ..         ...       ...         ...           ...        ...        ...
# 544  42.666667  2.556667         NaN  24321.000000  17.066667  85.333333
# 545  42.666667  2.556667         NaN  24321.000000  17.066667  85.333333
# 546  24.666667  2.610000        76.0    772.000000  25.900000  75.666667
# 547  24.666667  2.610000        76.0    772.000000  25.900000  75.666667
# 548  24.666667  2.610000        76.0    772.000000  25.900000  75.666667
#
#      diphtheria        hiv          gdp  total_expenditure  thinness_till19  \
# 0     31.000000   0.100000   139.967643           7.920000         8.100000
# 1     31.000000   0.100000   139.967643           7.920000         8.100000
# 2     31.000000   0.100000   139.967643           7.920000         8.100000
# 3     97.333333   0.100000  1318.801716           6.186667         2.066667
# 4     97.333333   0.100000  1318.801716           6.186667         2.066667
# ..          ...        ...          ...                ...              ...
# 544   84.666667  18.566667   365.788164           6.883333         7.433333
# 545   84.666667  18.566667   365.788164           6.883333         7.433333
# 546   74.666667  41.800000   384.431510           6.596667         4.600000
# 547   74.666667  41.800000   384.431510           6.596667         4.600000
# 548   74.666667  41.800000   384.431510           6.596667         4.600000
#
#      thinness_till9     school    population
# 0          2.366667   5.866667  8.413381e+06
# 1          2.366667   5.866667  8.413381e+06
# 2          2.366667   5.866667  8.413381e+06
# 3          2.133333  10.666667  2.620367e+04
# 4          2.133333  10.666667  2.620367e+04
# ..              ...        ...           ...
# 544        7.400000   9.800000  1.155532e+06
# 545        7.400000   9.800000  1.155532e+06
# 546        4.733333   9.866667  8.237980e+06
# 547        4.733333   9.866667  8.237980e+06
# 548        4.733333   9.866667  8.237980e+06
#
# [549 rows x 19 columns]

# %%
df.dtypes
# Out:
# country               object
# life_expectancy      float64
# year                   int64
# status                object
# adult_mortality      float64
# inf_death            float64
# alcohol              float64
# hepatitisB           float64
# measles              float64
# bmi                  float64
# polio                float64
# diphtheria           float64
# hiv                  float64
# gdp                  float64
# total_expenditure    float64
# thinness_till19      float64
# thinness_till9       float64
# school               float64
# population           float64
# dtype: object

# %%
def dsa_get_pairs(data, alvo, atributos, n):
    
    # Grupos de linhas com 3 (n) gráficos por linha
    grupos_linhas = [atributos[i:i+n] for i in range(0, len(atributos), n)]

    # Loop pelos grupos de linhas para criar cada pair plot
    for linha in grupos_linhas:
        plot = sns.pairplot(x_vars = linha, y_vars = alvo, data = data, kind = "reg", height = 3)

    return

# %%
alvo = ['life_expectancy']
atributos = ['population', 'hepatitisB', 'gdp', 'total_expenditure', 'alcohol', 'school']

# %%
dsa_get_pairs(df, alvo, atributos, 3)

# %%
valores_ausentes = df.isnull().sum().sort_values(ascending = False)
valores_ausentes
# Out:
# hepatitisB           210
# population           120
# gdp                   84
# school                30
# total_expenditure     12
# polio                  6
# thinness_till9         6
# thinness_till19        6
# diphtheria             6
# bmi                    6
# alcohol                3
# life_expectancy        0
# measles                0
# hiv                    0
# inf_death              0
# adult_mortality        0
# status                 0
# year                   0
# country                0
# dtype: int64

# %%
valores_ausentes_porcentagem = valores_ausentes[valores_ausentes > 0] / df.shape[0] 
valores_ausentes_porcentagem
# Out:
# hepatitisB           0.382514
# population           0.218579
# gdp                  0.153005
# school               0.054645
# total_expenditure    0.021858
# polio                0.010929
# thinness_till9       0.010929
# thinness_till19      0.010929
# diphtheria           0.010929
# bmi                  0.010929
# alcohol              0.005464
# dtype: float64

# %%
# identificando de outliers atraves do metodo do IQR (Interquartile Range)
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# %%
# definindo outliers com aqueles valores que estão fora do intervalo [Q1 - 1.5 * IQR, Q3 + 1.5 * IQR]
outliers = ((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum()
outliers
# Out:
# adult_mortality      36
# alcohol               0
# bmi                   0
# country               0
# diphtheria            0
# gdp                  63
# hepatitisB            0
# hiv                  84
# inf_death            57
# life_expectancy       0
# measles              81
# polio                 0
# population           48
# school                9
# status                0
# thinness_till19      12
# thinness_till9       18
# total_expenditure     6
# year                  0
# dtype: int64

# %%
# funcao para o replace das linhas vazias com a mediana
def impute_median(dados):
    return dados.fillna(dados.median())

# %%
df.population = df['population'].transform(impute_median) #
df.hepatitisB = df['hepatitisB'].transform(impute_median) #
df.alcohol = df['alcohol'].transform(impute_median) #
df.total_expenditure = df['total_expenditure'].transform(impute_median) #
df.gdp = df['gdp'].transform(impute_median) #
df.school = df['school'].transform(impute_median) #
df.polio = df['polio'].transform(impute_median) #
df.thinness_till9 = df['thinness_till9'].transform(impute_median) #
df.thinness_till19 = df['thinness_till19'].transform(impute_median) #
df.diphtheria = df['diphtheria'].transform(impute_median) #
df.bmi = df['bmi'].transform(impute_median) #

# %%
valores_ausentes = df.isnull().sum().sort_values(ascending = False)
valores_ausentes
# Out:
# country              0
# polio                0
# school               0
# thinness_till9       0
# thinness_till19      0
# total_expenditure    0
# gdp                  0
# hiv                  0
# diphtheria           0
# bmi                  0
# life_expectancy      0
# measles              0
# hepatitisB           0
# alcohol              0
# inf_death            0
# adult_mortality      0
# status               0
# year                 0
# population           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            549 non-null    object
#  1   life_expectancy    549 non-null    float64
#  2   year               549 non-null    int64
#  3   status             549 non-null    object
#  4   adult_mortality    549 non-null    float64
#  5   inf_death          549 non-null    float64
#  6   alcohol            549 non-null    float64
#  7   hepatitisB         549 non-null    float64
#  8   measles            549 non-null    float64
#  9   bmi                549 non-null    float64
#  10  polio              549 non-null    float64
#  11  diphtheria         549 non-null    float64
#  12  hiv                549 non-null    float64
#  13  gdp                549 non-null    float64
#  14  total_expenditure  549 non-null    float64
#  15  thinness_till19    549 non-null    float64
#  16  thinness_till9     549 non-null    float64
#  17  school             549 non-null    float64
#  18  population         549 non-null    float64
# dtypes: float64(16), int64(1), object(2)
# memory usage: 81.6+ KB

# %%
# correlacao das variaveis numericas no conjunto de dados
# hiv               -3.086350e-01 -1.672365e-01 -1.530360e-01  1.000000e+00
# gdp                3.274922e-01  3.142288e-01  2.529433e-01 -1.556740e-01
# total_expenditure  3.235013e-01  1.231452e-01  1.927498e-01  2.799536e-03
# thinness_till19   -6.211448e-01 -3.384556e-01 -3.044620e-01  2.583444e-01
# thinness_till9    -6.188749e-01 -2.913041e-01 -2.562227e-01  2.465614e-01
# school             5.659878e-01  4.603006e-01  4.437246e-01 -1.458937e-01
# population        -1.460762e-01 -6.460075e-02 -9.950437e-02  6.439828e-04
#
#                             gdp  total_expenditure  thinness_till19  \
# life_expectancy    4.960974e-01       2.086846e-01    -4.582103e-01
# year               1.627351e-14      -3.719404e-14    -6.462280e-14
# adult_mortality   -3.771639e-01      -6.881209e-02     3.356269e-01
# inf_death         -1.182133e-01      -1.522983e-01     4.927597e-01
# alcohol            4.341140e-01       3.271272e-01    -4.103368e-01
# hepatitisB         6.305029e-02      -7.514089e-03     2.469535e-02
# measles           -8.830305e-02      -1.321113e-01     3.260213e-01
# bmi                3.274922e-01       3.235013e-01    -6.211448e-01
# polio              3.142288e-01       1.231452e-01    -3.384556e-01
# diphtheria         2.529433e-01       1.927498e-01    -3.044620e-01
# hiv               -1.556740e-01       2.799536e-03     2.583444e-01
# gdp                1.000000e+00       1.632894e-01    -3.239494e-01
# total_expenditure  1.632894e-01       1.000000e+00    -3.150373e-01
# thinness_till19   -3.239494e-01      -3.150373e-01     1.000000e+00
# thinness_till9    -3.190345e-01      -3.585672e-01     9.359584e-01
# school             5.229003e-01       2.581096e-01    -3.757477e-01
# population        -7.767829e-02      -2.049632e-01     3.234084e-01
#
#                    thinness_till9        school    population
# life_expectancy     -4.130852e-01  6.680839e-01 -9.597717e-02
# year                -7.217727e-14  2.716252e-14 -4.893550e-14
# adult_mortality      3.143082e-01 -3.688992e-01  2.208955e-02
# inf_death            5.038642e-01 -1.720715e-01  5.017771e-01
# alcohol             -3.980204e-01  5.328811e-01 -1.245437e-02
# hepatitisB           1.094791e-02 -2.898799e-02 -5.465870e-02
# measles              3.103007e-01 -1.768569e-01  2.685114e-01
# bmi                 -6.188749e-01  5.659878e-01 -1.460762e-01
# polio               -2.913041e-01  4.603006e-01 -6.460075e-02
# diphtheria          -2.562227e-01  4.437246e-01 -9.950437e-02
# hiv                  2.465614e-01 -1.458937e-01  6.439828e-04
# gdp                 -3.190345e-01  5.229003e-01 -7.767829e-02
# total_expenditure   -3.585672e-01  2.581096e-01 -2.049632e-01
# thinness_till19      9.359584e-01 -3.757477e-01  3.234084e-01
# thinness_till9       1.000000e+00 -3.426811e-01  4.155947e-01
# school              -3.426811e-01  1.000000e+00 -8.821292e-02
# population           4.155947e-01 -8.821292e-02  1.000000e+00

# %%
# funcao para filtrar e visualizar correlacao
def filtrar_e_visualizar_correlacao(df, threshold, drop_column = None):

    # Calcula a matriz de correlação
    corr = df.corr()
    
    # Aplica os filtros de limiar, excluindo a correlação perfeita
    filtro = (abs(corr) >= threshold) & (corr != 1.0)
    df_filtrado = corr.where(filtro).dropna(how = 'all').dropna(axis = 1, how = 'all')
    
    # Remove a coluna e linha especificada, se fornecido
    if drop_column:
        df_filtrado = df_filtrado.drop(index = drop_column, 
                                       errors = 'ignore').drop(columns = drop_column, 
                                                               errors = 'ignore')
    
    # Visualiza o resultado com um heatmap somente com as variáveis que satisfazem o critério de filtro
    plt.figure(figsize = (8, 6))
    sns.heatmap(df_filtrado, annot = True, cmap = 'coolwarm', center = 0)
    plt.show()

# %%
# execucao da funcao
# para este caso, foi escolhido um threshold = 0.3 (filtro de correlacao)
# com as variaveis que apresentam correlacao maior que 0.3, seja ela positiva ou negativa.
filtrar_e_visualizar_correlacao(df, threshold = 0.3, drop_column = None)

# %%
# agora para realizar a regressao multipla vamos utilizar as variaveis
# adult_mortality, alcohol, bmi, polio, diphtheria, hiv, gdp, thinness_till19, thinness_till9, school e lifestyle 
# pois estas sao as que possuem uma correlacao maior com a variavel alvo
# mas antes, vamos verificar se existe muticolineariedade
# ou seja, se mais de uma variavel "representa a mesma coisa"
# para isso vamos considerar 0.5 como marca de corte. Vamos filtrar mais uma vez a matriz de correlação.

# %%
filtrar_e_visualizar_correlacao(df, threshold = 0.5, drop_column = 'life_expectancy')

# %%
# preparando o dataset final para a regressao multipla
df_final = pd.DataFrame({'life_expectancy': df['life_expectancy'],
                         'bmi': df['bmi'],
                         'adult_mortality': df['adult_mortality'],
                         'diphtheria': df['diphtheria'],
                         'hiv': df['hiv'],
                         'gdp': df['gdp'],
                         'thinness_till19': df['thinness_till19'],
                         'school': df['school'],
                        })

# %%
df_final
# Out:
#      life_expectancy        bmi  adult_mortality  diphtheria        hiv  \
# 0          55.433333  12.600000       213.333333   31.000000   0.100000
# 1          55.433333  12.600000       213.333333   31.000000   0.100000
# 2          55.433333  12.600000       213.333333   31.000000   0.100000
# 3          73.166667  45.966667        13.333333   97.333333   0.100000
# 4          73.166667  45.966667        13.333333   97.333333   0.100000
# ..               ...        ...              ...         ...        ...
# 544        44.633333  17.066667       431.333333   84.666667  18.566667
# 545        44.633333  17.066667       431.333333   84.666667  18.566667
# 546        45.366667  25.900000       474.666667   74.666667  41.800000
# 547        45.366667  25.900000       474.666667   74.666667  41.800000
# 548        45.366667  25.900000       474.666667   74.666667  41.800000
#
#              gdp  thinness_till19     school
# 0     139.967643         8.100000   5.866667
# 1     139.967643         8.100000   5.866667
# 2     139.967643         8.100000   5.866667
# 3    1318.801716         2.066667  10.666667
# 4    1318.801716         2.066667  10.666667
# ..           ...              ...        ...
# 544   365.788164         7.433333   9.800000
# 545   365.788164         7.433333   9.800000
# 546   384.431510         4.600000   9.866667
# 547   384.431510         4.600000   9.866667
# 548   384.431510         4.600000   9.866667
#
# [549 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression

# Definindo X e y
X = df_final[['bmi', 'adult_mortality', 'diphtheria', 'hiv', 'gdp', 'thinness_till19', 'school']]
y = df_final['life_expectancy']

# Criar e treinar o modelo
modelo = LinearRegression()
modelo.fit(X, y)

# Mostrar coeficientes
print("Intercepto (β₀):", modelo.intercept_)
print("Coeficientes (β₁, β₂, ...):", modelo.coef_)
print("R² (score):", modelo.score(X, y))
# Out:
# Intercepto (β₀): 49.39073629307368
# Coeficientes (β₁, β₂, ...): [ 1.08314787e-01 -1.75852729e-02  1.11265388e-01 -4.31866577e-01
#   1.40536182e-04  4.88857833e-02  7.94192108e-01]
# R² (score): 0.8310882535704728

# %%
# grafico
y_pred = modelo.predict(X)

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y, y=y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--r')  # Linha de referência (y=x)
plt.xlabel('Valor Real')
plt.ylabel('Valor Preditivo')
plt.title('Previsão vs. Real')
plt.show()
