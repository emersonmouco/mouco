# %%
import joblib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("espectativa_vida.csv")

# %%
novo_df = pd.DataFrame({'country': df['Country'],
                       'life_expectancy': df['Life expectancy '],
                       'year': df['Year'],
                       'status': df['Status'],
                       'adult_mortality': df['Adult Mortality'],
                       'inf_death': df['infant deaths'],
                       'alcohol': df['Alcohol'],
                       'hepatitisB': df['Hepatitis B'],
                       'measles': df['Measles '],
                       'bmi': df[' BMI '],
                       'polio': df['Polio'],
                       'diphtheria': df['Diphtheria '],
                       'hiv': df[' HIV/AIDS'],
                       'gdp': df['GDP'],
                       'total_expenditure': df['Total expenditure'],
                       'thinness_till19': df[' thinness  1-19 years'],
                       'thinness_till9': df[' thinness 5-9 years'],
                       'school': df['Schooling'],
                       'population': df[' Population']})

# %%
"""
def process_data(data, years, country, selected_columns):
    # Filtrar os dados pelos anos e pelo país especificado
    filtered_data = data[(data['Year'].isin(years)) & (data['Country'] == country)]
    
    # Calcular as médias apenas para as colunas selecionadas
    means = filtered_data[selected_columns].mean()
    
    # Substituir os valores apenas nas colunas selecionadas pelas médias
    for column in selected_columns:
        filtered_data[column] = means[column]
    
    return filtered_data
"""
def process_data(data, years, country):
    # Filtrar os dados pelos anos e pelo país especificado
    filtered_data = data[(data['year'].isin(years)) & (data['country'] == country)]
    
    # Selecionar as colunas numéricas, excluindo "Year"
    numeric_columns = filtered_data.select_dtypes(include='number').columns
    numeric_columns = [col for col in numeric_columns if col != 'year']
    
    # Calcular as médias para as colunas selecionadas
    means = filtered_data[numeric_columns].mean()
    
    # Substituir os valores nas colunas selecionadas pelas médias
    for column in numeric_columns:
        filtered_data[column] = means[column]
    
    return filtered_data


### verificar para pular o indice a cada tres linhas e calcular a media dos proximos tres.
### ou verificar, onde os anos forem iguais a 2000, 2001 e 2002, ele calcula a media e
### e coloca nas variaveis numericas, depois ele faz o mesmo passo para as proximas tres linhas e anos etc

# %%
novo_df
# Out:
#           country  life_expectancy  year      status  adult_mortality  \
# 0     Afghanistan             65.0  2015  Developing            263.0
# 1     Afghanistan             59.9  2014  Developing            271.0
# 2     Afghanistan             59.9  2013  Developing            268.0
# 3     Afghanistan             59.5  2012  Developing            272.0
# 4     Afghanistan             59.2  2011  Developing            275.0
# ...           ...              ...   ...         ...              ...
# 2933     Zimbabwe             44.3  2004  Developing            723.0
# 2934     Zimbabwe             44.5  2003  Developing            715.0
# 2935     Zimbabwe             44.8  2002  Developing             73.0
# 2936     Zimbabwe             45.3  2001  Developing            686.0
# 2937     Zimbabwe             46.0  2000  Developing            665.0
#
#       inf_death  alcohol  hepatitisB  measles   bmi  polio  diphtheria   hiv  \
# ...

# %%
# Exemplo de uso:
# Criando um DataFrame de exemplo
data = novo_df

# Anos e País para filtrar
years = [2000, 2001, 2002]
country = 'Brazil'

# colunas que serao imputadas as medias
# selected_columns = []

# Processar os dados
# processed_data = process_data(data, years, country, selected_columns)
processed_data = process_data(data, years, country)
print(processed_data)
# Out:
#     country  life_expectancy  year      status  adult_mortality  inf_death  \
# 365  Brazil        72.466667  2002  Developing       179.333333      103.0
# 366  Brazil        72.466667  2001  Developing       179.333333      103.0
# 367  Brazil        72.466667  2000  Developing       179.333333      103.0
#
#      alcohol  hepatitisB    measles   bmi  polio  diphtheria  hiv         gdp  \
# 365     7.13   92.333333  12.666667  44.5   99.0   98.333333  0.1  3235.24022
# 366     7.13   92.333333  12.666667  44.5   99.0   98.333333  0.1  3235.24022
# 367     7.13   92.333333  12.666667  44.5   99.0   98.333333  0.1  3235.24022
#
#      total_expenditure  thinness_till19  thinness_till9     school  \
# 365           7.206667         3.366667        3.366667  14.333333
# 366           7.206667         3.366667        3.366667  14.333333
# 367           7.206667         3.366667        3.366667  14.333333
#
#        population
# 365  5.962676e+07
# 366  5.962676e+07
# 367  5.962676e+07

# %%
processed_data
# Out:
#     country  life_expectancy  year      status  adult_mortality  inf_death  \
# 365  Brazil        72.466667  2002  Developing       179.333333      103.0
# 366  Brazil        72.466667  2001  Developing       179.333333      103.0
# 367  Brazil        72.466667  2000  Developing       179.333333      103.0
#
#      alcohol  hepatitisB    measles   bmi  polio  diphtheria  hiv         gdp  \
# 365     7.13   92.333333  12.666667  44.5   99.0   98.333333  0.1  3235.24022
# 366     7.13   92.333333  12.666667  44.5   99.0   98.333333  0.1  3235.24022
# 367     7.13   92.333333  12.666667  44.5   99.0   98.333333  0.1  3235.24022
#
#      total_expenditure  thinness_till19  thinness_till9     school  \
# 365           7.206667         3.366667        3.366667  14.333333
# 366           7.206667         3.366667        3.366667  14.333333
# 367           7.206667         3.366667        3.366667  14.333333
#
#        population
# 365  5.962676e+07
# 366  5.962676e+07
# 367  5.962676e+07

# %%
#df_2014 = df[novo_df['year'].astype(str) == '2014']
#df_2014.to_csv('dados_2014.csv', index=False)
#df = pd.read_csv("dados_2014.csv")
df_filtrado = df[novo_df['year'].isin([2000, 2001, 2002])]

# %%
df_filtrado
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 13    Afghanistan  2002  Developing              56.2              3.0
# 14    Afghanistan  2001  Developing              55.3            316.0
# 15    Afghanistan  2000  Developing              54.8            321.0
# 29        Albania  2002  Developing              73.3             15.0
# 30        Albania  2001  Developing              73.6             14.0
# ...           ...   ...         ...               ...              ...
# 2920       Zambia  2001  Developing              44.6            611.0
# 2921       Zambia  2000  Developing              43.8            614.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
#  Population                        float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...
